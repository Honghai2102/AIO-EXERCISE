# %% [markdown]
# <a href="https://colab.research.google.com/github/Honghai2102/AIO-EXERCISE/blob/feature%2FM05EX03/Predicting_Car_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown --id 1qiUDDoYyRLBiKOoYWdFl_5WByHE8Cugu
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1qiUDDoYyRLBiKOoYWdFl_5WByHE8Cugu
# To: /content/Auto_MPG_data.csv
# 100% 15.4k/15.4k [00:00<00:00, 27.6MB/s]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
random_state = 59
np.random.seed(random_state)
torch.manual_seed(random_state)
if torch.cuda.is_available():
    torch.cuda.manual_seed(random_state)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
dataset_path = '/content/Auto_MPG_data.csv'
dataset = pd.read_csv(dataset_path)
dataset
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0        86.0  2790.0          15.6
# 388  44.0          4          97.0        52.0  2130.0          24.6
# 389  32.0          4         135.0        84.0  2295.0          11.6
# 390  28.0          4         120.0        79.0  2625.0          18.6
# 391  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Europe  Japan  USA
# 0            70       0      0    1
# 1            70       0      0    1
# 2            70       0      0    1
# 3            70       0      0    1
# 4            70       0      0    1
# ..          ...     ...    ...  ...
# 387          82       0      0    1
# 388          82       1      0    0
# 389          82       0      0    1
# 390          82       0      0    1
# 391          82       0      0    1
#
# [392 rows x 10 columns]

# %%
X = dataset.drop(columns='MPG').values
y = dataset['MPG'].values

# %%
val_size = 0.2
test_size = 0.125
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

# %%
print(f'Number of training samples: {X_train.shape[0]}')
print(f'Number of val samples: {X_val.shape[0]}')
print(f'Number of test samples: {X_test.shape[0]}')
# Out:
# Number of training samples: 273
# Number of val samples: 79
# Number of test samples: 40

# %%
normalizer = StandardScaler()
X_train = normalizer.fit_transform(X_train)
X_val = normalizer.transform(X_val)
X_test = normalizer.transform(X_test)

X_train = torch.tensor(X_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
batch_size = 32
train_dataset = CustomDataset(X_train, y_train)
val_dataset = CustomDataset(X_val, y_val)
train_loader = DataLoader(train_dataset,
                          batch_size = batch_size,
                          shuffle=True)
val_loader = DataLoader(val_dataset,
                        batch_size = batch_size,
                        shuffle=True)

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super().__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims)
        self.linear2 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

    def forward(self, x):
      x = self.linear1(x)
      x = F.relu(x)
      x = self.linear2(x)
      x = F.relu(x)
      out = self.output(x)
      return out.squeeze(1)

# %%
input_dims = X_train.shape[1]
output_dims = 1
hidden_dims = 64

model = MLP(input_dims=input_dims,
            hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)

# %%
lr = 1e-2
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %%
def r_squared(y_true, y_pred):
  y_true = torch.Tensor(y_true).to(device)
  y_pred = torch.Tensor(y_pred).to(device)
  mean_true = torch.mean(y_true)
  ss_tot = torch.sum((y_true - mean_true) ** 2)
  ss_res = torch.sum((y_true - y_pred) ** 2)
  r2 = 1 - (ss_res / ss_tot)
  return r2

# %%
epochs = 100
train_losses = []
val_losses = []
train_r2 = []
val_r2 = []

# %%
for epoch in range(epochs):
    train_loss = 0.0
    train_target = []
    val_target = []
    train_predict = []
    val_predict = []
    model.train()
    for X_samples, y_samples in train_loader:
        X_samples = X_samples.to(device)
        y_samples = y_samples.to(device)
        optimizer.zero_grad()
        outputs = model(X_samples)
        train_predict += outputs.tolist()
        train_target += y_samples.tolist()
        loss = criterion(outputs, y_samples)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    train_r2.append(r_squared(train_target, train_predict))
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for X_samples, y_samples in val_loader:
            X_samples = X_samples.to(device)
            y_samples = y_samples.to(device)
            outputs = model(X_samples)
            val_predict += outputs.tolist()
            val_target += y_samples.tolist()
            loss = criterion(outputs, y_samples)
            val_loss += loss.item()
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_r2.append(r_squared(val_target, val_predict))
    print(f'\nEPOCH {epoch + 1}:\tTraining loss: {train_loss:.3f}\tValidation loss: {val_loss:.3f}')
# Out:
# EPOCH 1:	Training loss: 282.769	Validation loss: 95.338
#
# EPOCH 2:	Training loss: 221.958	Validation loss: 14.701
#
# EPOCH 3:	Training loss: 64.707	Validation loss: 61.322
#
# EPOCH 4:	Training loss: 56.295	Validation loss: 11.470
#
# EPOCH 5:	Training loss: 15.991	Validation loss: 29.043
#
# EPOCH 6:	Training loss: 13.585	Validation loss: 5.645
#
# EPOCH 7:	Training loss: 16.962	Validation loss: 30.514
#
# EPOCH 8:	Training loss: 19.340	Validation loss: 25.458
#
# EPOCH 9:	Training loss: 15.598	Validation loss: 10.553
#
# EPOCH 10:	Training loss: 19.680	Validation loss: 13.447
#
# EPOCH 11:	Training loss: 17.543	Validation loss: 8.199
#
# EPOCH 12:	Training loss: 11.291	Validation loss: 40.754
#
# EPOCH 13:	Training loss: 18.568	Validation loss: 13.712
#
# EPOCH 14:	Training loss: 8.181	Validation loss: 17.474
#
# EPOCH 15:	Training loss: 9.779	Validation loss: 6.069
#
# EPOCH 16:	Training loss: 7.622	Validation loss: 5.138
#
# EPOCH 17:	Training loss: 6.634	Validation loss: 5.355
#
# EPOCH 18:	Training loss: 7.559	Validation loss: 5.863
#
# EPOCH 19:	Training loss: 7.900	Validation loss: 9.139
#
# EPOCH 20:	Training loss: 11.622	Validation loss: 6.194
#
# EPOCH 21:	Training loss: 10.628	Validation loss: 12.895
#
# EPOCH 22:	Training loss: 7.772	Validation loss: 13.697
#
# EPOCH 23:	Training loss: 17.170	Validation loss: 14.354
#
# EPOCH 24:	Training loss: 8.916	Validation loss: 13.512
#
# EPOCH 25:	Training loss: 10.174	Validation loss: 5.059
#
# EPOCH 26:	Training loss: 13.924	Validation loss: 10.097
#
# EPOCH 27:	Training loss: 10.557	Validation loss: 9.774
#
# EPOCH 28:	Training loss: 7.013	Validation loss: 6.813
#
# EPOCH 29:	Training loss: 6.569	Validation loss: 19.490
#
# EPOCH 30:	Training loss: 9.610	Validation loss: 6.321
#
# EPOCH 31:	Training loss: 6.764	Validation loss: 25.766
#
# EPOCH 32:	Training loss: 7.831	Validation loss: 4.991
#
# EPOCH 33:	Training loss: 7.155	Validation loss: 7.964
#
# EPOCH 34:	Training loss: 7.661	Validation loss: 6.532
#
# EPOCH 35:	Training loss: 7.973	Validation loss: 8.457
#
# EPOCH 36:	Training loss: 6.871	Validation loss: 11.984
#
# EPOCH 37:	Training loss: 8.086	Validation loss: 11.126
#
# EPOCH 38:	Training loss: 9.715	Validation loss: 7.328
#
# EPOCH 39:	Training loss: 9.092	Validation loss: 7.589
#
# EPOCH 40:	Training loss: 8.980	Validation loss: 5.244
#
# EPOCH 41:	Training loss: 6.453	Validation loss: 6.330
#
# EPOCH 42:	Training loss: 7.640	Validation loss: 12.894
#
# EPOCH 43:	Training loss: 9.066	Validation loss: 8.637
#
# EPOCH 44:	Training loss: 6.526	Validation loss: 5.554
#
# EPOCH 45:	Training loss: 9.495	Validation loss: 5.658
#
# EPOCH 46:	Training loss: 6.456	Validation loss: 16.514
#
# EPOCH 47:	Training loss: 7.740	Validation loss: 5.931
#
# EPOCH 48:	Training loss: 5.612	Validation loss: 5.346
#
# EPOCH 49:	Training loss: 8.180	Validation loss: 6.694
#
# EPOCH 50:	Training loss: 6.544	Validation loss: 6.476
#
# EPOCH 51:	Training loss: 8.322	Validation loss: 6.672
#
# EPOCH 52:	Training loss: 10.356	Validation loss: 8.204
#
# EPOCH 53:	Training loss: 12.702	Validation loss: 6.905
#
# EPOCH 54:	Training loss: 5.643	Validation loss: 6.270
#
# EPOCH 55:	Training loss: 5.882	Validation loss: 8.318
#
# EPOCH 56:	Training loss: 6.819	Validation loss: 8.187
#
# EPOCH 57:	Training loss: 6.052	Validation loss: 5.452
#
# EPOCH 58:	Training loss: 7.646	Validation loss: 8.377
#
# EPOCH 59:	Training loss: 5.824	Validation loss: 7.038
#
# EPOCH 60:	Training loss: 5.612	Validation loss: 6.114
#
# EPOCH 61:	Training loss: 13.299	Validation loss: 8.183
#
# EPOCH 62:	Training loss: 6.699	Validation loss: 7.248
#
# EPOCH 63:	Training loss: 9.283	Validation loss: 8.518
#
# EPOCH 64:	Training loss: 6.669	Validation loss: 8.044
#
# EPOCH 65:	Training loss: 6.035	Validation loss: 12.356
#
# EPOCH 66:	Training loss: 6.792	Validation loss: 5.952
#
# EPOCH 67:	Training loss: 4.990	Validation loss: 6.655
#
# EPOCH 68:	Training loss: 5.810	Validation loss: 11.492
#
# EPOCH 69:	Training loss: 9.074	Validation loss: 7.406
#
# EPOCH 70:	Training loss: 6.713	Validation loss: 6.156
#
# EPOCH 71:	Training loss: 6.639	Validation loss: 12.218
#
# EPOCH 72:	Training loss: 7.652	Validation loss: 12.531
#
# EPOCH 73:	Training loss: 6.844	Validation loss: 9.869
#
# EPOCH 74:	Training loss: 6.836	Validation loss: 6.267
#
# EPOCH 75:	Training loss: 5.910	Validation loss: 6.189
#
# EPOCH 76:	Training loss: 6.022	Validation loss: 31.972
#
# EPOCH 77:	Training loss: 12.758	Validation loss: 5.734
#
# EPOCH 78:	Training loss: 6.367	Validation loss: 6.754
#
# EPOCH 79:	Training loss: 7.960	Validation loss: 5.221
#
# EPOCH 80:	Training loss: 5.001	Validation loss: 6.776
#
# EPOCH 81:	Training loss: 4.587	Validation loss: 4.863
#
# EPOCH 82:	Training loss: 5.756	Validation loss: 6.580
#
# EPOCH 83:	Training loss: 5.855	Validation loss: 10.949
#
# EPOCH 84:	Training loss: 9.011	Validation loss: 8.124
#
# EPOCH 85:	Training loss: 6.024	Validation loss: 7.258
#
# EPOCH 86:	Training loss: 5.975	Validation loss: 18.456
#
# EPOCH 87:	Training loss: 17.928	Validation loss: 9.920
#
# EPOCH 88:	Training loss: 9.217	Validation loss: 12.742
#
# EPOCH 89:	Training loss: 6.225	Validation loss: 4.072
#
# EPOCH 90:	Training loss: 6.832	Validation loss: 5.946
#
# EPOCH 91:	Training loss: 5.050	Validation loss: 4.704
#
# EPOCH 92:	Training loss: 6.135	Validation loss: 8.518
#
# EPOCH 93:	Training loss: 7.036	Validation loss: 6.158
#
# EPOCH 94:	Training loss: 6.870	Validation loss: 9.319
#
# EPOCH 95:	Training loss: 6.048	Validation loss: 10.921
#
# EPOCH 96:	Training loss: 6.552	Validation loss: 7.393
#
# EPOCH 97:	Training loss: 6.509	Validation loss: 6.085
#
# EPOCH 98:	Training loss: 5.233	Validation loss: 5.999
#
# EPOCH 99:	Training loss: 4.784	Validation loss: 7.346
#
# EPOCH 100:	Training loss: 5.852	Validation loss: 8.891

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_losses, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_r2, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='R2')
ax[1, 0].set_title('Training R2')

ax[1, 1].plot(val_r2, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='R2')
ax[1, 1].set_title('Validation R2')

plt.show()

# %%
model.eval()
with torch.no_grad():
    y_hat = model(X_val)
    val_set_r2 = r_squared(y_hat, y_val)
    print('Evaluation on validation set:')
    print(f'R2: {val_set_r2}')
# Out:
# Evaluation on validation set:
# R2: 0.8961862921714783
