# %%
import pandas as pd
import numpy as np
import re
import nltk
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from nltk.tokenize import TweetTokenizer
from collections import defaultdict

# %%
dataset_path = 'sentiment_analysis.csv'
df = pd.read_csv(
dataset_path,
index_col ='id'
)
df
# Out:
#       label                                              tweet
# id
# 1         0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 2         0  Finally a transparant silicon case ^^ Thanks t...
# 3         0  We love this! Would you go? #talk #makememorie...
# 4         0  I'm wired I know I'm George I was made that wa...
# 5         1  What amazing service! Apple won't even talk to...
# ...     ...                                                ...
# 7916      0  Live out loud #lol #liveoutloud #selfie #smile...
# 7917      0  We would like to wish you an amazing day! Make...
# 7918      0  Helping my lovely 90 year old neighbor with he...
# 7919      0  Finally got my #smart #pocket #wifi stay conne...
# 7920      0  Apple Barcelona!!! #Apple #Store #BCN #Barcelo...
#
# [7920 rows x 2 columns]

# %%
def text_normalize ( text ) :
    # Retweet old acronym "RT" removal
    text = re.sub(r'^RT [\s]+', '', text)

    # Hyperlinks removal
    text = re.sub(r'https ?:\/\/.*[\ r\n]* ', '', text)

    # Hashtags removal
    text = re.sub(r'#', '', text )

    # Punctuation removal
    text = re.sub(r'[^\ w\s]', '', text )

    # Tokenization
    tokenizer = TweetTokenizer (
    preserve_case=False,
    strip_handles=True,
    reduce_len=True
    )
    text_tokens = tokenizer.tokenize ( text )

    return text_tokens

# %%
def get_freqs(df) :
    freqs = defaultdict(lambda : 0)
    for idx, row in df.iterrows():
        tweet = row ['tweet']
        label = row ['label']

        tokens = text_normalize (tweet)
        for token in tokens:
            pair = (token, label )
            freqs[pair] += 1

    return freqs

# %%
def get_feature(text, freqs) :
    tokens = text_normalize(text)

    X = np.zeros(3)
    X[0] = 1

    for token in tokens :
        X[1] += freqs[(token, 0)]
        X[2] += freqs[(token, 1)]

    return X

# %%
X = []
y = []

freqs = get_freqs (df)
for idx, row in df.iterrows ():
    tweet = row ['tweet']
    label = row ['label']

    X_i = get_feature(tweet , freqs)
    X.append(X_i)
    y.append(label)

X = np.array(X)
y = np.array(y)

# %%
val_size = 0.2
test_size = 0.125
random_state = 1
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)

# %%
normalizer = StandardScaler ()
X_train[:, 1:] = normalizer.fit_transform(X_train[: , 1:])
X_val[:, 1:] = normalizer.transform(X_val[: , 1:])
X_test[:, 1:] = normalizer.transform(X_test[: , 1:])

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def predict(X, theta):
    dot_product = np.dot(X, theta)
    y_hat = sigmoid(dot_product)
    
    return y_hat

def compute_loss(y_hat, y):
    y_hat = np.clip(
        y_hat, 1e-7, 1 - 1e-7
    )
    return (
        -y * \
        np.log(y_hat) - (1 - y) * \
        np.log(1 - y_hat)
    ).mean()
    
def compute_gradient(X, y, y_hat):
    return np.dot(
        X.T, (y_hat - y)
    ) / y.size
    
def update_theta(theta, gradient, lr):
    return theta - lr * gradient

def compute_accuracy(X, y, theta):
    y_hat = predict(X, theta).round()
    acc = (y_hat == y).mean()
    
    return acc

# %%
lr = 0.01
epochs = 200
batch_size = 128

np.random.seed(random_state)
theta = np.random.uniform(
    size = X_train.shape[1]
)

# %%
train_accs = []
train_losses = []
val_accs = []
val_losses = []

for epoch in range(epochs):
    train_batch_loesses = []
    train_batch_accs = []
    val_batch_loesses = []
    val_batch_accs = []
    
    for i in range(0, X_train.shape[0], batch_size):
        X_i = X_train[i:i+batch_size]
        y_i = y_train[i:i+batch_size]
        
        y_hat = predict(X_i, theta)
        
        train_loss = compute_loss(y_hat, y_i)
        
        gradient = compute_gradient(X_i, y_i, y_hat)
        
        theta = update_theta(theta, gradient, lr)
        
        train_batch_loesses.append(train_loss)
        
        train_acc = compute_accuracy(X_train, y_train, theta)
        train_batch_accs.append(train_acc)
        
        y_val_hat = predict(X_val, theta)
        val_loss = compute_loss(y_val_hat, y_val)
        val_batch_loesses.append(val_loss)
        
        val_acc = compute_accuracy(X_val, y_val, theta)
        val_batch_accs.append(val_acc)
        
    train_batch_loss = sum(train_batch_loesses) / len(train_batch_loesses)
    val_batch_loss = sum(val_batch_loesses) / len(val_batch_loesses)
    train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
    val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)
    
    train_losses.append(train_batch_loss)
    val_losses.append(val_batch_loss)
    train_accs.append(train_batch_acc)
    val_accs.append(val_batch_acc)
    
    print(f'\nEPOCH {epoch +1 }: \tTraining loss: {train_batch_loss:.3f}\tValidation loss: {val_batch_loss:.3f}')
# Out:
# EPOCH 1: 	Training loss: 0.857	Validation loss: 0.847
#
# EPOCH 2: 	Training loss: 0.801	Validation loss: 0.794
#
# EPOCH 3: 	Training loss: 0.755	Validation loss: 0.750
#
# EPOCH 4: 	Training loss: 0.718	Validation loss: 0.715
#
# EPOCH 5: 	Training loss: 0.688	Validation loss: 0.687
#
# EPOCH 6: 	Training loss: 0.664	Validation loss: 0.666
#
# EPOCH 7: 	Training loss: 0.646	Validation loss: 0.648
#
# EPOCH 8: 	Training loss: 0.631	Validation loss: 0.635
#
# EPOCH 9: 	Training loss: 0.619	Validation loss: 0.624
#
# EPOCH 10: 	Training loss: 0.610	Validation loss: 0.616
#
# EPOCH 11: 	Training loss: 0.602	Validation loss: 0.609
#
# EPOCH 12: 	Training loss: 0.596	Validation loss: 0.603
#
# EPOCH 13: 	Training loss: 0.591	Validation loss: 0.599
#
# EPOCH 14: 	Training loss: 0.587	Validation loss: 0.595
#
# EPOCH 15: 	Training loss: 0.583	Validation loss: 0.592
#
# EPOCH 16: 	Training loss: 0.580	Validation loss: 0.590
#
# EPOCH 17: 	Training loss: 0.578	Validation loss: 0.588
#
# EPOCH 18: 	Training loss: 0.576	Validation loss: 0.586
#
# EPOCH 19: 	Training loss: 0.574	Validation loss: 0.585
#
# EPOCH 20: 	Training loss: 0.573	Validation loss: 0.584
#
# EPOCH 21: 	Training loss: 0.572	Validation loss: 0.583
#
# EPOCH 22: 	Training loss: 0.571	Validation loss: 0.582
#
# EPOCH 23: 	Training loss: 0.570	Validation loss: 0.581
#
# EPOCH 24: 	Training loss: 0.569	Validation loss: 0.581
#
# EPOCH 25: 	Training loss: 0.569	Validation loss: 0.581
#
# EPOCH 26: 	Training loss: 0.568	Validation loss: 0.580
#
# EPOCH 27: 	Training loss: 0.568	Validation loss: 0.580
#
# EPOCH 28: 	Training loss: 0.567	Validation loss: 0.580
#
# EPOCH 29: 	Training loss: 0.567	Validation loss: 0.580
#
# EPOCH 30: 	Training loss: 0.567	Validation loss: 0.579
#
# EPOCH 31: 	Training loss: 0.566	Validation loss: 0.579
#
# EPOCH 32: 	Training loss: 0.566	Validation loss: 0.579
#
# EPOCH 33: 	Training loss: 0.566	Validation loss: 0.579
#
# EPOCH 34: 	Training loss: 0.566	Validation loss: 0.579
#
# EPOCH 35: 	Training loss: 0.566	Validation loss: 0.579
#
# EPOCH 36: 	Training loss: 0.566	Validation loss: 0.579
#
# EPOCH 37: 	Training loss: 0.566	Validation loss: 0.579
#
# EPOCH 38: 	Training loss: 0.566	Validation loss: 0.579
#
# EPOCH 39: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 40: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 41: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 42: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 43: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 44: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 45: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 46: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 47: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 48: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 49: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 50: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 51: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 52: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 53: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 54: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 55: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 56: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 57: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 58: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 59: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 60: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 61: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 62: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 63: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 64: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 65: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 66: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 67: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 68: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 69: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 70: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 71: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 72: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 73: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 74: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 75: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 76: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 77: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 78: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 79: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 80: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 81: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 82: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 83: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 84: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 85: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 86: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 87: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 88: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 89: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 90: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 91: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 92: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 93: 	Training loss: 0.565	Validation loss: 0.579
#
# EPOCH 94: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 95: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 96: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 97: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 98: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 99: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 100: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 101: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 102: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 103: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 104: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 105: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 106: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 107: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 108: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 109: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 110: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 111: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 112: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 113: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 114: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 115: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 116: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 117: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 118: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 119: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 120: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 121: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 122: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 123: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 124: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 125: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 126: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 127: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 128: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 129: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 130: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 131: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 132: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 133: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 134: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 135: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 136: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 137: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 138: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 139: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 140: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 141: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 142: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 143: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 144: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 145: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 146: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 147: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 148: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 149: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 150: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 151: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 152: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 153: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 154: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 155: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 156: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 157: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 158: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 159: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 160: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 161: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 162: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 163: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 164: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 165: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 166: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 167: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 168: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 169: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 170: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 171: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 172: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 173: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 174: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 175: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 176: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 177: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 178: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 179: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 180: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 181: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 182: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 183: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 184: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 185: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 186: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 187: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 188: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 189: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 190: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 191: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 192: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 193: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 194: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 195: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 196: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 197: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 198: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 199: 	Training loss: 0.565	Validation loss: 0.580
#
# EPOCH 200: 	Training loss: 0.565	Validation loss: 0.580

# %%
fig, ax = plt.subplots(2, 2, figsize = (12, 10))
ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel='Epoch ', ylabel ='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, 'orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss ')

ax[1, 0].plot(train_accs)
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_accs , 'orange')
ax[1, 1].set(xlabel ='Epoch', ylabel ='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.show()

# %%
val_set_acc = compute_accuracy(X_val, y_val, theta)
test_set_acc = compute_accuracy( X_test, y_test, theta)
print('Evaluation on validation and test set :')
print(f'Accuracy : { val_set_acc }')
print(f'Accuracy : { test_set_acc }')
# Out:
# Evaluation on validation and test set :
# Accuracy : 0.7335858585858586
# Accuracy : 0.7436908517350158
