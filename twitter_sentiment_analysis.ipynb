# %% [markdown]
# <a href="https://colab.research.google.com/github/Honghai2102/AIO-EXERCISE/blob/feature%2FM05EX02/twitter_sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import nltk
nltk.download ('stopwords')

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
dataset_path = 'Twitter_Data.csv'
df = pd. read_csv (
dataset_path
)
df
# Out:
#                                                clean_text  category
# 0       when modi promised “minimum government maximum...      -1.0
# 1       talk all the nonsense and continue all the dra...       0.0
# 2       what did just say vote for modi  welcome bjp t...       1.0
# 3       asking his supporters prefix chowkidar their n...       1.0
# 4       answer who among these the most powerful world...       1.0
# ...                                                   ...       ...
# 162975  why these 456 crores paid neerav modi not reco...      -1.0
# 162976  dear rss terrorist payal gawar what about modi...      -1.0
# 162977  did you cover her interaction forum where she ...       0.0
# 162978  there big project came into india modi dream p...       0.0
# 162979  have you ever listen about like gurukul where ...       1.0
#
# [162980 rows x 2 columns]

# %%
df = df.dropna()

# %%
def text_normalize(text):
    # Lowercasing
    text = text.lower()

    # Retweet old acronym "RT" removal
    text = re.sub(r'^rt [\s]+', '', text)

    # Hyperlinks removal
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text)

    # Punctuation removal
    text = re.sub(r'[^\w\s]', '', text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = text.split()
    words = [word for word in words if word not in stop_words]
    text = ' '.join(words)

    # Stemming
    stemmer = SnowballStemmer('english')
    words = text.split()
    words = [stemmer.stem(word) for word in words]
    text = ' '.join(words)

    return text

# %%
vectorizer = TfidfVectorizer(max_features =2000)
X = vectorizer . fit_transform(df['clean_text']).toarray()

# %%
intercept = np.ones((
    X.shape[0], 1
))
X_b = np.concatenate(
    (intercept, X),
    axis = 1
)

# %%
n_classes = df['category'].nunique()
n_samples = df['category'].size

y = df['category'].to_numpy() + 1
y = y.astype(np.uint8)

y_encoded = np.array(
    [np.zeros(n_classes) for _ in range(n_samples)]
)
y_encoded[np.arange(n_samples), y] = 1

# %%
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X_b, y_encoded,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

# %%
def softmax(z):
    exp_z = np.exp(z)
    return exp_z / exp_z.sum(axis=1)[:, None]

def predict(X,theta):
    z = np.dot(X, theta)
    y_hat = softmax(z)
    return y_hat

def compute_loss(y_hat, y):
    n = y.size
    return (-1/n)*np.sum(y * np.log(y_hat))

def compute_gradient(X, y, y_hat):
    n = y.size
    return np.dot(X.T, (y_hat - y)) / n

def update_theta(theta, gradient, lr):
    return theta - lr*gradient

def compute_accuracy(X, y, theta):
    y_hat = predict(X, theta)
    acc = (np.argmax(y_hat, axis=1) == np.argmax(y, axis=1)).mean()
    return acc

# %%
lr = 0.01
epochs = 200
batch_size = X_train.shape[0]
n_features = X_train.shape[1]

np.random.seed(random_state)
theta = np.random.uniform(
    size=(n_features, n_classes)
)

# %%
train_accs = []
train_losses = []
val_accs = []
val_losses = []

for epoch in range(epochs):
    train_batch_loesses = []
    train_batch_accs = []
    val_batch_loesses = []
    val_batch_accs = []

    for i in range(0, X_train.shape[0], batch_size):
        X_i = X_train[i:i+batch_size]
        y_i = y_train[i:i+batch_size]

        y_hat = predict(X_i, theta)

        train_loss = compute_loss(y_hat, y_i)

        gradient = compute_gradient(X_i, y_i, y_hat)

        theta = update_theta(theta, gradient, lr)

        train_batch_loesses.append(train_loss)

        train_acc = compute_accuracy(X_train, y_train, theta)
        train_batch_accs.append(train_acc)

        y_val_hat = predict(X_val, theta)
        val_loss = compute_loss(y_val_hat, y_val)
        val_batch_loesses.append(val_loss)

        val_acc = compute_accuracy(X_val, y_val, theta)
        val_batch_accs.append(val_acc)

    train_batch_loss = sum(train_batch_loesses) / len(train_batch_loesses)
    val_batch_loss = sum(val_batch_loesses) / len(val_batch_loesses)
    train_batch_acc = sum(train_batch_accs) / len(train_batch_accs)
    val_batch_acc = sum(val_batch_accs) / len(val_batch_accs)

    train_losses.append(train_batch_loss)
    val_losses.append(val_batch_loss)
    train_accs.append(train_batch_acc)
    val_accs.append(val_batch_acc)

    print(f'\nEPOCH {epoch +1 }: \tTraining loss: {train_batch_loss:.3f}\tValidation loss: {val_batch_loss:.3f}')
# Out:
# EPOCH 1: 	Training loss: 0.377	Validation loss: 0.376
#
# EPOCH 2: 	Training loss: 0.377	Validation loss: 0.376
#
# EPOCH 3: 	Training loss: 0.377	Validation loss: 0.376
#
# EPOCH 4: 	Training loss: 0.377	Validation loss: 0.376
#
# EPOCH 5: 	Training loss: 0.377	Validation loss: 0.376
#
# EPOCH 6: 	Training loss: 0.377	Validation loss: 0.375
#
# EPOCH 7: 	Training loss: 0.377	Validation loss: 0.375
#
# EPOCH 8: 	Training loss: 0.377	Validation loss: 0.375
#
# EPOCH 9: 	Training loss: 0.377	Validation loss: 0.375
#
# EPOCH 10: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 11: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 12: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 13: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 14: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 15: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 16: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 17: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 18: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 19: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 20: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 21: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 22: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 23: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 24: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 25: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 26: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 27: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 28: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 29: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 30: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 31: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 32: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 33: 	Training loss: 0.376	Validation loss: 0.375
#
# EPOCH 34: 	Training loss: 0.376	Validation loss: 0.374
#
# EPOCH 35: 	Training loss: 0.376	Validation loss: 0.374
#
# EPOCH 36: 	Training loss: 0.376	Validation loss: 0.374
#
# EPOCH 37: 	Training loss: 0.376	Validation loss: 0.374
#
# EPOCH 38: 	Training loss: 0.376	Validation loss: 0.374
#
# EPOCH 39: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 40: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 41: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 42: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 43: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 44: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 45: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 46: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 47: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 48: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 49: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 50: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 51: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 52: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 53: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 54: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 55: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 56: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 57: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 58: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 59: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 60: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 61: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 62: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 63: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 64: 	Training loss: 0.375	Validation loss: 0.374
#
# EPOCH 65: 	Training loss: 0.375	Validation loss: 0.373
#
# EPOCH 66: 	Training loss: 0.375	Validation loss: 0.373
#
# EPOCH 67: 	Training loss: 0.375	Validation loss: 0.373
#
# EPOCH 68: 	Training loss: 0.375	Validation loss: 0.373
#
# EPOCH 69: 	Training loss: 0.375	Validation loss: 0.373
#
# EPOCH 70: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 71: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 72: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 73: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 74: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 75: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 76: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 77: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 78: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 79: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 80: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 81: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 82: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 83: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 84: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 85: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 86: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 87: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 88: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 89: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 90: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 91: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 92: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 93: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 94: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 95: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 96: 	Training loss: 0.374	Validation loss: 0.373
#
# EPOCH 97: 	Training loss: 0.374	Validation loss: 0.372
#
# EPOCH 98: 	Training loss: 0.374	Validation loss: 0.372
#
# EPOCH 99: 	Training loss: 0.374	Validation loss: 0.372
#
# EPOCH 100: 	Training loss: 0.374	Validation loss: 0.372
#
# EPOCH 101: 	Training loss: 0.374	Validation loss: 0.372
#
# EPOCH 102: 	Training loss: 0.374	Validation loss: 0.372
#
# EPOCH 103: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 104: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 105: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 106: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 107: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 108: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 109: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 110: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 111: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 112: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 113: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 114: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 115: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 116: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 117: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 118: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 119: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 120: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 121: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 122: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 123: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 124: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 125: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 126: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 127: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 128: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 129: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 130: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 131: 	Training loss: 0.373	Validation loss: 0.372
#
# EPOCH 132: 	Training loss: 0.373	Validation loss: 0.371
#
# EPOCH 133: 	Training loss: 0.373	Validation loss: 0.371
#
# EPOCH 134: 	Training loss: 0.373	Validation loss: 0.371
#
# EPOCH 135: 	Training loss: 0.373	Validation loss: 0.371
#
# EPOCH 136: 	Training loss: 0.373	Validation loss: 0.371
#
# EPOCH 137: 	Training loss: 0.373	Validation loss: 0.371
#
# EPOCH 138: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 139: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 140: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 141: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 142: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 143: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 144: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 145: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 146: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 147: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 148: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 149: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 150: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 151: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 152: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 153: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 154: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 155: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 156: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 157: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 158: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 159: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 160: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 161: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 162: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 163: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 164: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 165: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 166: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 167: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 168: 	Training loss: 0.372	Validation loss: 0.371
#
# EPOCH 169: 	Training loss: 0.372	Validation loss: 0.370
#
# EPOCH 170: 	Training loss: 0.372	Validation loss: 0.370
#
# EPOCH 171: 	Training loss: 0.372	Validation loss: 0.370
#
# EPOCH 172: 	Training loss: 0.372	Validation loss: 0.370
#
# EPOCH 173: 	Training loss: 0.372	Validation loss: 0.370
#
# EPOCH 174: 	Training loss: 0.372	Validation loss: 0.370
#
# EPOCH 175: 	Training loss: 0.372	Validation loss: 0.370
#
# EPOCH 176: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 177: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 178: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 179: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 180: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 181: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 182: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 183: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 184: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 185: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 186: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 187: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 188: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 189: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 190: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 191: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 192: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 193: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 194: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 195: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 196: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 197: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 198: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 199: 	Training loss: 0.371	Validation loss: 0.370
#
# EPOCH 200: 	Training loss: 0.371	Validation loss: 0.370

# %%
fig, ax = plt.subplots(2, 2, figsize = (12, 10))
ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel='Epoch ', ylabel ='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, 'orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss ')

ax[1, 0].plot(train_accs)
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_accs , 'orange')
ax[1, 1].set(xlabel ='Epoch', ylabel ='Accuracy')
ax[1, 1].set_title('Validation Accuracy')



plt.show()

# %%
val_set_acc = compute_accuracy(X_val , y_val , theta)
test_set_acc = compute_accuracy ( X_test , y_test , theta )
print ('Evaluation on validation and test set :')
print (f'Accuracy : { val_set_acc }')
print (f'Accuracy : { test_set_acc }')
# Out:
# Evaluation on validation and test set :
# Accuracy : 0.39507271276922135
# Accuracy : 0.3884764067006197
